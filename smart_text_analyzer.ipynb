# %% [markdown]
# # Smart Text Analyzer
# Mini Project using python Strings

# %%
### print("===== SMART TEXT ANALYSER ======")
text = input("Enter a sentence:")
print("\nChoose an option:")
print("1. Convert to UPPERCASE")
print("2. Convert to Lowercase")
print("3. Slice the text")
print("4. Count a word")
print("5. Replace a word")
print("6. Passward checker")
print("7. Exit ")
choice = int(input("Enter your choice (1-7): "))
if choice ==1:
    print("Result:", text.upper())
elif choice == 2:
    print("Result:", text.lower())
elif choice == 3:
    start = int(input("Enter start index: "))
    end = int(input("Enter end index:"))
    print("sliced text:",text[start:end])
elif choice == 4:
    word = input("Enter word to count:")
    print("Count:", text.count(word))
elif choice == 5:
    old = input("Enter word to replace:")
    new = input("Enter new word: ")
    print("updated text:",utext.replace(old, new))
elif choice == 6:
    passward = inpuut("Enter your passward:")
    if len(passward)>= 8 and passward.isalnum():
        print("Strong passward")
    else:
        print("weak passward")
        
elif choice == 7:
    print("Exiting program...")
else:
    print("Invalid choice")
# Out:
# Enter a sentence: Python programing is fun and powerful
# Choose an option:
# 1. Convert to UPPERCASE
# 2. Convert to Lowercase
# 3. Slice the text
# 4. Count a word
# 5. Replace a word
# 6. Passward checker
# 7. Exit
# Enter your choice (1-7):  3
# Enter start index:  7
# Enter end index: 17
# sliced text: programing
